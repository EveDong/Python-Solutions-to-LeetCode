# %%
class Queue:
    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the queue to be k.
        """
        self.front = -1
        self.rear = -1
        self.size = k
        self.data = {}

    def enQueue(self, value: int) -> bool:
        """
        Insert an element into the circular queue. Return true if the operation is successful.
        """
        if self.rear == self.size - 1:
            return False
        else:
            self.rear += 1
            self.data[self.rear] = value
            return True

    def deQueue(self) -> bool:
        """
        Delete an element from the circular queue. Return true if the operation is successful.
        """
        if self.isEmpty():
            return False
        else:
            del self.data[self.front]
            self.front += 1
            return True

    def Front(self) -> int:
        """
        Get the front item from the queue.
        """
        if self.isEmpty():
            return -1
        return self.data[self.front]

    def Rear(self) -> int:
        """
        Get the last item from the queue.
        """
        if self.isEmpty():
            return -1
        return self.data[self.rear]

    def isEmpty(self) -> bool:
        """
        Checks whether the circular queue is empty or not.
        """
        return self.rear == self.front

    def isFull(self) -> bool:
        """
        Checks whether the circular queue is full or not.
        """
        return self.rear - self.front == self.size - 1


# Your MyCircularQueue object will be instantiated and called as such:
# obj = MyCircularQueue(k)
# param_1 = obj.enQueue(value)
# param_2 = obj.deQueue()
# param_3 = obj.Front()
# param_4 = obj.Rear()
# param_5 = obj.isEmpty()
# param_6 = obj.isFull()

# %%
class CircularQueue:
    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the queue to be k.
        """
        self.front = 0
        self.rear = 0
        self.size = k + 1  # 区分空栈与满栈
        self.count = 0  # 推荐使用
        self.data = [None for i in range(self.size)]

    def enQueue(self, value: int) -> bool:
        """
        Insert an element into the circular queue. Return true if the operation is successful.
        """
        if self.isFull():
            return False
        else:
            self.data[self.rear] = value
            self.rear = (self.rear + 1) % self.size
            self.count += 1
            return True

    def deQueue(self) -> bool:
        """
        Delete an element from the circular queue. Return true if the operation is successful.
        """
        if self.isEmpty():
            return False
        else:
            self.data[self.front] = None
            self.front = (self.front + 1) % self.size
            self.count -= 1
            return True

    def Front(self) -> int:
        """
        Get the front item from the queue.
        """
        if self.isEmpty():
            return -1
        else:
            return self.data[self.front]

    def Rear(self) -> int:
        """
        Get the last item from the queue.
        """
        if self.isEmpty():
            return -1
        else:
            return self.data[(self.rear - 1) % self.size]
            return self.data[(self.front + self.count) % self.size]

    def isEmpty(self) -> bool:
        """
        Checks whether the circular queue is empty or not.
        """
        return self.front == self.rear
        return self.count == 0

    def isFull(self) -> bool:
        """
        Checks whether the circular queue is full or not.
        """
        return (self.rear + 1) % self.size == self.front  # 入栈追上出栈
        return self.count == self.size


# Your MyCircularQueue object will be instantiated and called as such:
# obj = MyCircularQueue(k)
# param_1 = obj.enQueue(value)
# param_2 = obj.deQueue()
# param_3 = obj.Front()
# param_4 = obj.Rear()
# param_5 = obj.isEmpty()
# param_6 = obj.isFull()

# %% [markdown]
# # 346. Moving Average from Data Stream

# %%
class MovingAverage:
    def __init__(self, size: int):
        """
        Initialize your data structure here.
        """
        self.rear = 0
        self.data = [None] * size
        self.size = size  # 无需判断入队追上出队，无需额外空间
        self.sum = 0  # 使用sum记录之前的求和结果，省去再次求和的步骤
        self.count = 0

    def next(self, val: int) -> float:
        self.sum += val
        if self.count < self.size:
            self.count += 1
            self.data[self.rear] = val
            self.rear = (self.rear + 1) % self.size
            return self.sum / self.count
        else:
            self.sum -= self.data[self.rear]
            self.data[self.rear] = val
            self.rear = (self.rear + 1) % self.size
            return self.sum / self.count


# Your MovingAverage object will be instantiated and called as such:
# obj = MovingAverage(size)
# param_1 = obj.next(val)

# %%
class MovingAverage:
    def __init__(self, size: int):
        """
        Initialize your data structure here.
        """
        self.rear = 0
        self.count = 0
        self.size = size + 1
        self.data = [None] * self.size

    def next(self, val: int) -> float:
        self.data[self.rear] = val
        self.rear = (self.rear + 1) % self.size
        if self.count < self.size - 1:
            self.count += 1
        sum = 0
        for i in range(self.count):
            sum += self.data[self.rear - 1 - i]
        return sum / self.count


# Your MovingAverage object will be instantiated and called as such:
# obj = MovingAverage(size)
# param_1 = obj.next(val)
